# %%
# !pip list | grep sagemaker
# Out:
# sagemaker                          2.117.0
# sagemaker-pyspark                  1.4.2

# %%
import boto3
import sagemaker
from sagemaker.pytorch import PyTorch

session=boto3.session.Session()
sagemaker_session = sagemaker.session.Session(boto_session=session)

# %%
# !pygmentize test_ep.sh
# Out:
# #!/bin/bash
# echo "num args: $#"
# echo "args: $@"

# %%
estimator = PyTorch(
    base_job_name="sh-ep-check",
    source_dir=".",
    entry_point="test_ep.sh",
#     entry_point="test_ep.py",
    role=sagemaker.get_execution_role(),
    image_uri="570106654206.dkr.ecr.us-west-2.amazonaws.com/pzesheng-dev:dlc-1.12.1-base",
    instance_count=2,
    instance_type="ml.p4d.24xlarge",
    sagemaker_session=sagemaker_session,
    hyperparameters={"size-list": "33554432 67108864 1073741824"},
    distribution={'pytorchddp': {'enabled': True}},
    debugger_hook_config=False,
)

estimator.fit()
# Out:
# 2023-01-09 16:24:01 Starting - Starting the training job...ProfilerReport-1673281441: InProgress
# ...
# 2023-01-09 16:24:45 Starting - Preparing the instances for training.........
# 2023-01-09 16:26:26 Downloading - Downloading input data...
# 2023-01-09 16:26:46 Training - Downloading the training image..................
# 2023-01-09 16:29:47 Training - Training image download completed. Training in progress.....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-09 16:30:35,073 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-09 16:30:35,146 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-09 16:30:35,148 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel for native PT DDP job
# 2023-01-09 16:30:35,148 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-09 16:30:35,579 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-09 16:30:35,579 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2023-01-09 16:30:35,589 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2023-01-09 16:30:35,589 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.90.89.              Can be ignored for worker when master completes and exits.
# 2023-01-09 16:30:36,592 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2023-01-09 16:30:36,593 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.90.89.              Can be ignored for worker when master completes and exits.
# 2023-01-09 16:30:37,596 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2023-01-09 16:30:37,596 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.90.89.              Can be ignored for worker when master completes and exits.
# 2023-01-09 16:30:38,598 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2023-01-09 16:30:38,599 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.90.89.              Can be ignored for worker when master completes and exits.
# 2023-01-09 16:30:39,608 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-09 16:30:39,738 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-09 16:30:39,738 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2023-01-09 16:30:39,738 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2023-01-09 16:30:39,738 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2023-01-09 16:30:39,744 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2023-01-09 16:30:41,752 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=51, name='orted', status='sleeping', started='16:30:41')]
# 2023-01-09 16:30:41,752 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=51, name='orted', status='sleeping', started='16:30:41')]
# 2023-01-09 16:30:41,752 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=51, name='orted', status='sleeping', started='16:30:41')]
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-09 16:30:38,645 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-09 16:30:38,720 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-09 16:30:38,722 sagemaker_pytorch_container.training INFO     Invoking SMDataParallel for native PT DDP job
# 2023-01-09 16:30:38,722 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-09 16:30:39,133 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-09 16:30:39,133 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2023-01-09 16:30:39,134 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2023-01-09 16:30:39,136 sagemaker-training-toolkit INFO     Cannot connect to host algo-2 at port 22. Retrying...
# 2023-01-09 16:30:39,137 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-09 16:30:40,148 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-09 16:30:40,274 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-09 16:30:40,275 sagemaker-training-toolkit INFO     Can connect to host algo-2 at port 22
# 2023-01-09 16:30:40,275 sagemaker-training-toolkit INFO     Connection closed
# 2023-01-09 16:30:40,275 sagemaker-training-toolkit INFO     Worker algo-2 available for communication
# 2023-01-09 16:30:40,275 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2023-01-09 16:30:40,275 sagemaker-training-toolkit INFO     Host: ['algo-1', 'algo-2']
# 2023-01-09 16:30:40,276 sagemaker-training-toolkit INFO     instance type: ml.p4d.24xlarge
# 2023-01-09 16:30:40,276 sagemaker-training-toolkit INFO     Env Hosts: ['algo-1', 'algo-2'] Hosts: ['algo-1:8', 'algo-2:8'] process_per_hosts: 8 num_processes: 16
# 2023-01-09 16:30:40,351 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_instance_type": "ml.p4d.24xlarge",
#         "sagemaker_pytorch_ddp_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "current_instance_type": "ml.p4d.24xlarge",
#     "distribution_hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "distribution_instance_groups": [
#         "homogeneousCluster"
#     ],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "size-list": "33554432 67108864 1073741824"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.p4d.24xlarge",
#             "hosts": [
#                 "algo-1",
#                 "algo-2"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "job_name": "sh-ep-check-2023-01-09-16-24-01-138",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-570106654206/sh-ep-check-2023-01-09-16-24-01-138/source/sourcedir.tar.gz",
#     "module_name": "test_ep.sh",
#     "network_interface_name": "eth0",
#     "num_cpus": 96,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p4d.24xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p4d.24xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "test_ep.sh"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"size-list":"33554432 67108864 1073741824"}
# SM_USER_ENTRY_POINT=test_ep.sh
# SM_FRAMEWORK_PARAMS={"sagemaker_instance_type":"ml.p4d.24xlarge","sagemaker_pytorch_ddp_enabled":true}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p4d.24xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.p4d.24xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1","algo-2"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_IS_HETERO=false
# SM_MODULE_NAME=test_ep.sh
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=96
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-570106654206/sh-ep-check-2023-01-09-16-24-01-138/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_instance_type":"ml.p4d.24xlarge","sagemaker_pytorch_ddp_enabled":true},"channel_input_dirs":{},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1","algo-2"],"current_instance_type":"ml.p4d.24xlarge","distribution_hosts":["algo-1","algo-2"],"distribution_instance_groups":["homogeneousCluster"],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"size-list":"33554432 67108864 1073741824"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"job_name":"sh-ep-check-2023-01-09-16-24-01-138","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-570106654206/sh-ep-check-2023-01-09-16-24-01-138/source/sourcedir.tar.gz","module_name":"test_ep.sh","network_interface_name":"eth0","num_cpus":96,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p4d.24xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"test_ep.sh"}
# SM_USER_ARGS=["--size-list","33554432 67108864 1073741824"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_SIZE-LIST=33554432 67108864 1073741824
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.22b20221003-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# Invoking script with the following command:
# mpirun --host algo-1:8,algo-2:8 -np 16 --allow-run-as-root --tag-output --oversubscribe -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -mca plm_rsh_num_concurrent 2 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x SMDATAPARALLEL_USE_HOMOGENEOUS=1 -x FI_PROVIDER=efa -x RDMAV_FORK_SAFE=1 -x LD_PRELOAD=/opt/conda/lib/python3.8/site-packages/gethostname.cpython-38-x86_64-linux-gnu.so -x FI_EFA_USE_DEVICE_RDMA=1 -x NCCL_PROTO=simple -x SMDATAPARALLEL_SERVER_ADDR=algo-1 -x SMDATAPARALLEL_SERVER_PORT=7592 -x SAGEMAKER_INSTANCE_TYPE=ml.p4d.24xlarge smddprun /bin/sh -c "./test_ep.sh --size-list '33554432 67108864 1073741824'"
# Warning: Permanently added 'algo-2,10.0.124.215' (ECDSA) to the list of known hosts.
# [1,mpirank:0,algo-1]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:8,algo-2]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:0,algo-1]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:8,algo-2]<stderr>:curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# [1,mpirank:4,algo-1]<stdout>:num args: 0
# [1,mpirank:4,algo-1]<stdout>:args:
# [1,mpirank:3,algo-1]<stdout>:num args: 0
# [1,mpirank:3,algo-1]<stdout>:args:
# [1,mpirank:11,algo-2]<stdout>:num args: 0
# [1,mpirank:11,algo-2]<stdout>:args:
# [1,mpirank:9,algo-2]<stdout>:num args: 0
# [1,mpirank:9,algo-2]<stdout>:args:
# [1,mpirank:14,algo-2]<stdout>:num args: 0
# [1,mpirank:14,algo-2]<stdout>:args:
# [1,mpirank:10,algo-2]<stdout>:num args: 0
# [1,mpirank:10,algo-2]<stdout>:args:
# [1,mpirank:15,algo-2]<stdout>:num args: 0
# [1,mpirank:15,algo-2]<stdout>:args:
# [1,mpirank:13,algo-2]<stdout>:num args: 0
# [1,mpirank:13,algo-2]<stdout>:args:
# [1,mpirank:12,algo-2]<stdout>:num args: 0
# [1,mpirank:12,algo-2]<stdout>:args:
# [1,mpirank:7,algo-1]<stdout>:num args: 0
# [1,mpirank:7,algo-1]<stdout>:args:
# [1,mpirank:6,algo-1]<stdout>:num args: 0
# [1,mpirank:6,algo-1]<stdout>:args:
# [1,mpirank:1,algo-1]<stdout>:num args: 0
# [1,mpirank:1,algo-1]<stdout>:args:
# [1,mpirank:5,algo-1]<stdout>:num args: 0
# [1,mpirank:5,algo-1]<stdout>:args:
# [1,mpirank:2,algo-1]<stdout>:num args: 0
# [1,mpirank:2,algo-1]<stdout>:args:
# [1,mpirank:8,algo-2]<stdout>:num args: 0
# [1,mpirank:8,algo-2]<stdout>:args:
# [1,mpirank:0,algo-1]<stdout>:num args: 0
# [1,mpirank:0,algo-1]<stdout>:args:
# 2023-01-09 16:30:42,282 sagemaker-training-toolkit INFO     Waiting for the process to finish and give a return code.
# 2023-01-09 16:30:42,282 sagemaker-training-toolkit INFO     Done waiting for a return code. Received 0 from exiting process.
# 2023-01-09 16:30:42,283 sagemaker-training-toolkit INFO     Begin writing status file from leader node to worker nodes
# 2023-01-09 16:30:42,283 sagemaker-training-toolkit INFO     Start writing mpirun finished status to algo-2
# 2023-01-09 16:30:42,285 sagemaker-training-toolkit INFO     Invoked on_terminate from psutil.wait_for_procs
# 2023-01-09 16:30:42,286 sagemaker-training-toolkit INFO     process psutil.Process(pid=51, name='orted', status='terminated', started='16:30:41') terminated with exit code None
# 2023-01-09 16:30:42,286 sagemaker-training-toolkit INFO     Reporting status for ORTEd process. gone: [psutil.Process(pid=51, name='orted', status='terminated', started='16:30:41')] alive: []
# 2023-01-09 16:30:42,286 sagemaker-training-toolkit INFO     Orted process exited
# 2023-01-09 16:30:42,427 sagemaker-training-toolkit INFO     output from subprocess run CompletedProcess(args=['ssh', 'algo-2', 'touch', '/tmp/done.algo-1'], returncode=0, stdout='', stderr='')
# 2023-01-09 16:30:42,427 sagemaker-training-toolkit INFO     Finished writing status file
# 2023-01-09 16:31:12,316 sagemaker-training-toolkit INFO     Begin looking for status file on algo-2
# 2023-01-09 16:31:12,316 sagemaker-training-toolkit INFO     MPI training job status file found. Exit gracefully
# 2023-01-09 16:31:12,317 sagemaker-training-toolkit INFO     End looking for status file
# 2023-01-09 16:31:12,317 sagemaker-training-toolkit INFO     MPI process finished.
# 2023-01-09 16:31:12,317 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2023-01-09 16:31:12,445 sagemaker-training-toolkit INFO     Finished writing status file from leader node to worker nodes
# 2023-01-09 16:31:12,446 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2023-01-09 16:31:27 Uploading - Uploading generated training model
# 2023-01-09 16:31:27 Completed - Training job completed
# Training seconds: 606
# Billable seconds: 606
