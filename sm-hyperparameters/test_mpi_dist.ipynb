# %%
# !pip list | grep sagemaker
# Out:
# sagemaker                          2.117.0
# sagemaker-pyspark                  1.4.2

# %%
import boto3
import sagemaker
from sagemaker.pytorch import PyTorch

session=boto3.session.Session()
sagemaker_session = sagemaker.session.Session(boto_session=session)

# %%
# !pygmentize test_ep.sh
# Out:
# #!/bin/bash
# echo "num args: $#"
# echo "args: $@"

# %%
estimator = PyTorch(
    base_job_name="sh-ep-check",
    source_dir=".",
    entry_point="test_ep.sh",
#     entry_point="test_ep.py",
    role=sagemaker.get_execution_role(),
    image_uri="570106654206.dkr.ecr.us-west-2.amazonaws.com/pzesheng-dev:dlc-1.12.1-base",
    instance_count=2,
    instance_type="ml.p4d.24xlarge",
    sagemaker_session=sagemaker_session,
    hyperparameters={"size-list": "33554432 67108864 1073741824"},
    distribution={"mpi": {"enabled": True}},
    debugger_hook_config=False,
)

estimator.fit()
# Out:
# 2023-01-10 00:44:04 Starting - Starting the training job...ProfilerReport-1673311444: InProgress
# ...
# 2023-01-10 00:44:50 Starting - Preparing the instances for training.........
# 2023-01-10 00:46:28 Downloading - Downloading input data...
# 2023-01-10 00:46:48 Training - Downloading the training image...............
# 2023-01-10 00:49:29 Training - Training image download completed. Training in progress......bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-10 00:50:17,118 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-10 00:50:17,192 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-10 00:50:17,194 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-10 00:50:17,575 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-10 00:50:17,575 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2023-01-10 00:50:17,576 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2023-01-10 00:50:17,578 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2023-01-10 00:50:17,578 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.111.61.              Can be ignored for worker when master completes and exits.
# 2023-01-10 00:50:18,580 sagemaker-training-toolkit INFO     Cannot connect to host algo-1
# 2023-01-10 00:50:18,580 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.111.61.              Can be ignored for worker when master completes and exits.
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-10 00:50:16,918 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-10 00:50:16,992 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-10 00:50:16,994 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-10 00:50:17,451 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2023-01-10 00:50:17,451 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# 2023-01-10 00:50:17,458 sagemaker-training-toolkit INFO     Cannot connect to host algo-2
# 2023-01-10 00:50:17,458 sagemaker-training-toolkit INFO     Connection failed with exception:
#  [Errno None] Unable to connect to port 22 on 10.0.66.92.              Can be ignored for worker when master completes and exits.
# 2023-01-10 00:50:18,469 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-10 00:50:18,600 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-10 00:50:18,600 sagemaker-training-toolkit INFO     Can connect to host algo-2
# 2023-01-10 00:50:18,600 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# 2023-01-10 00:50:18,600 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# 2023-01-10 00:50:18,606 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# 2023-01-10 00:50:19,592 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_8.2p1)
# 2023-01-10 00:50:19,719 paramiko.transport INFO     Authentication (publickey) successful!
# 2023-01-10 00:50:19,719 sagemaker-training-toolkit INFO     Can connect to host algo-1
# 2023-01-10 00:50:19,719 sagemaker-training-toolkit INFO     Worker algo-1 available for communication
# 2023-01-10 00:50:19,720 sagemaker-training-toolkit INFO     Env Hosts: ['algo-2', 'algo-1'] Hosts: ['algo-2:8', 'algo-1:8'] process_per_hosts: 8 num_processes: 16
# 2023-01-10 00:50:19,721 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2023-01-10 00:50:19,799 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_custom_mpi_options": "",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-2",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-2",
#         "algo-1"
#     ],
#     "current_instance_type": "ml.p4d.24xlarge",
#     "distribution_hosts": [
#         "algo-2",
#         "algo-1"
#     ],
#     "distribution_instance_groups": [
#         "homogeneousCluster"
#     ],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "size-list": "33554432 67108864 1073741824"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.p4d.24xlarge",
#             "hosts": [
#                 "algo-2",
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "job_name": "sh-ep-check-2023-01-10-00-44-03-931",
#     "log_level": 20,
#     "master_hostname": "algo-2",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-570106654206/sh-ep-check-2023-01-10-00-44-03-931/source/sourcedir.tar.gz",
#     "module_name": "test_ep.sh",
#     "network_interface_name": "eth0",
#     "num_cpus": 96,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "current_instance_type": "ml.p4d.24xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p4d.24xlarge",
#                 "hosts": [
#                     "algo-2",
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "test_ep.sh"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"size-list":"33554432 67108864 1073741824"}
# SM_USER_ENTRY_POINT=test_ep.sh
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.p4d.24xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-2","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-2
# SM_CURRENT_INSTANCE_TYPE=ml.p4d.24xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-2","algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-2","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_IS_HETERO=false
# SM_MODULE_NAME=test_ep.sh
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=96
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-570106654206/sh-ep-check-2023-01-10-00-44-03-931/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true},"channel_input_dirs":{},"current_host":"algo-2","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-2","algo-1"],"current_instance_type":"ml.p4d.24xlarge","distribution_hosts":["algo-2","algo-1"],"distribution_instance_groups":["homogeneousCluster"],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"size-list":"33554432 67108864 1073741824"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-2","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"job_name":"sh-ep-check-2023-01-10-00-44-03-931","log_level":20,"master_hostname":"algo-2","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-570106654206/sh-ep-check-2023-01-10-00-44-03-931/source/sourcedir.tar.gz","module_name":"test_ep.sh","network_interface_name":"eth0","num_cpus":96,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.p4d.24xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-2","algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p4d.24xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"test_ep.sh"}
# SM_USER_ARGS=["--size-list","33554432 67108864 1073741824"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_SIZE-LIST=33554432 67108864 1073741824
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.22b20221003-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# Invoking script with the following command:
# mpirun --host algo-2:8,algo-1:8 -np 16 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/opt/conda/lib/python3.8/site-packages/gethostname.cpython-38-x86_64-linux-gnu.so -x FI_PROVIDER=efa -x FI_EFA_USE_DEVICE_RDMA=1 -x NCCL_PROTO=simple -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_CURRENT_INSTANCE_TYPE -x SM_CURRENT_INSTANCE_GROUP -x SM_CURRENT_INSTANCE_GROUP_HOSTS -x SM_INSTANCE_GROUPS -x SM_INSTANCE_GROUPS_DICT -x SM_DISTRIBUTION_INSTANCE_GROUPS -x SM_IS_HETERO -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_HP_SIZE-LIST -x PYTHONPATH /bin/sh -c "./test_ep.sh --size-list '33554432 67108864 1073741824'"
# [algo-2:00113] Warning: could not find environment variable "SM_HP_SIZE-LIST"
# Warning: Permanently added 'algo-1,10.0.111.61' (ECDSA) to the list of known hosts.
# Data for JOB [22869,1] offset 0 Total slots allocated 16
#  ========================   JOB MAP   ========================
#  Data for node: algo-2#011Num slots: 8#011Max slots: 0#011Num procs: 8
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 0 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 1 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 2 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 3 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 4 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 5 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 6 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 7 Bound: N/A
#  Data for node: algo-1#011Num slots: 8#011Max slots: 0#011Num procs: 8
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 8 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 9 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 10 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 11 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 12 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 13 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 14 Bound: N/A
#  #011Process OMPI jobid: [22869,1] App: 0 Process rank: 15 Bound: N/A
#  =============================================================
# [1,mpirank:0,algo-1]<stdout>:num args: 2
# [1,mpirank:0,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:1,algo-1]<stdout>:num args: 2
# [1,mpirank:1,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:2,algo-1]<stdout>:num args: 2
# [1,mpirank:2,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:3,algo-1]<stdout>:num args: 2
# [1,mpirank:3,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:4,algo-1]<stdout>:num args: 2
# [1,mpirank:4,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:5,algo-1]<stdout>:num args: 2
# [1,mpirank:5,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:6,algo-1]<stdout>:num args: 2
# [1,mpirank:6,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:7,algo-1]<stdout>:num args: 2
# [1,mpirank:7,algo-1]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:8,algo-2]<stdout>:num args: 2
# [1,mpirank:8,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:9,algo-2]<stdout>:num args: 2
# [1,mpirank:9,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:10,algo-2]<stdout>:num args: 2
# [1,mpirank:10,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:11,algo-2]<stdout>:num args: 2
# [1,mpirank:11,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:12,algo-2]<stdout>:num args: 2
# [1,mpirank:12,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:13,algo-2]<stdout>:num args: 2
# [1,mpirank:13,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:14,algo-2]<stdout>:num args: 2
# [1,mpirank:14,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# [1,mpirank:15,algo-2]<stdout>:num args: 2
# [1,mpirank:15,algo-2]<stdout>:args: --size-list 33554432 67108864 1073741824
# 2023-01-10 00:50:21,156 sagemaker-training-toolkit INFO     Waiting for the process to finish and give a return code.
# 2023-01-10 00:50:21,157 sagemaker-training-toolkit INFO     Done waiting for a return code. Received 0 from exiting process.
# 2023-01-10 00:50:21,157 sagemaker-training-toolkit INFO     Begin writing status file from leader node to worker nodes (if any)
# 2023-01-10 00:50:21,157 sagemaker-training-toolkit INFO     Start writing mpirun finished status to algo-1
# 2023-01-10 00:50:21,306 sagemaker-training-toolkit INFO     output from subprocess run CompletedProcess(args=['ssh', 'algo-1', 'touch', '/tmp/done.algo-2'], returncode=0, stdout='', stderr='')
# 2023-01-10 00:50:21,306 sagemaker-training-toolkit INFO     Finished writing status file
# 2023-01-10 00:50:51,336 sagemaker-training-toolkit INFO     Finished writing status file from leader node to worker nodes (if any)
# 2023-01-10 00:50:51,337 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2023-01-10 00:55:19,144 sagemaker-training-toolkit INFO     Orted process found None
# 2023-01-10 00:55:19,145 sagemaker-training-toolkit INFO     Waiting for orted process None
# 2023-01-10 00:55:19,147 sagemaker-training-toolkit ERROR    Reporting training FAILURE
# 2023-01-10 00:55:19,147 sagemaker-training-toolkit ERROR    Framework Error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/trainer.py", line 87, in train
#     entrypoint()
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_pytorch_container/training.py", line 145, in main
#     train(environment.Environment())
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_pytorch_container/training.py", line 92, in train
#     entry_point.run(uri=training_environment.module_dir,
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/entry_point.py", line 99, in run
#     return runner.get(runner_type, user_entry_point, args, env_vars, extra_opts).run(
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/mpi.py", line 114, in run
#     gone, alive = _wait_orted_process_to_finish()
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/mpi.py", line 166, in _wait_orted_process_to_finish
#     gone, alive = psutil.wait_procs(orted, callback=_on_terminate)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/__init__.py", line 1526, in wait_procs
#     alive = set(procs)
# TypeError: 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 2023-01-10 00:55:19,147 sagemaker-training-toolkit ERROR    Encountered exit_code 1
#
# 2023-01-10 00:55:30 Uploading - Uploading generated training model
# 2023-01-10 00:55:30 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-14-2d4ef292b6ab> in <module>
#      14 )
#      15
# ---> 16 estimator.fit()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/workflow/pipeline_context.py in wrapper(*args, **kwargs)
#     270             return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
#     271
# --> 272         return run_func(*args, **kwargs)
#     273
#     274     return wrapper
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#    1126         self.jobs.append(self.latest_training_job)
#    1127         if wait:
# -> 1128             self.latest_training_job.wait(logs=logs)
#    1129
#    1130     def _compilation_job_name(self):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    2240         # If logs are requested, call logs_for_jobs.
#    2241         if logs != "None":
# -> 2242             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    2243         else:
#    2244             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3891
#    3892         if wait:
# -> 3893             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3894             if dot:
#    3895                 print()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3432                 message=message,
#    3433                 allowed_statuses=["Completed", "Stopped"],
# -> 3434                 actual_status=status,
#    3435             )
#    3436
#
# UnexpectedStatusException: Error for Training job sh-ep-check-2023-01-10-00-44-03-931: Failed. Reason: AlgorithmError: Framework Error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/trainer.py", line 87, in train
#     entrypoint()
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_pytorch_container/training.py", line 145, in main
#     train(environment.Environment())
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_pytorch_container/training.py", line 92, in train
#     entry_point.run(uri=training_environment.module_dir,
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/entry_point.py", line 99, in run
#     return runner.get(runner_type, user_entry_point, args, env_vars, extra_opts).run(
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/mpi.py", line 114, in run
#     gone, alive = _wait_orted_process_to_finish()
#   File "/opt/conda/lib/python3.8/site-packages/sagemaker_training/mpi.py", line 166, in _wait_orted_process_to_finish
#     gone, alive = psutil.wait_procs(orted, callback=_on_terminate)
#   File "/opt/conda/li
